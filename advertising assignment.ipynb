# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
data=pd.read_csv('advertising.csv',sep=',')
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#Distribution of TV advertising spending
plt.figure(figsize=(8,4))
sns.histplot(data["TV"],bins=5)
plt.title('TV Advertising Distribution')
plt.xlabel('TV')
plt.ylabel('Frequency')
plt.show()

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
#Distribution of Radio Advertising spending
plt.figure(figsize=(8,4))
sns.histplot(data['Radio'], bins=5,kde=True,color='black')
plt.title('Radio Advertising Distribution')
plt.xlabel('Radio')
plt.ylabel('Frequency')
plt.show()

# %%
#Distribution of Newspaper Advertising Spending
plt.figure(figsize =(8,4))
sns.histplot(data['Newspaper'], bins=5,color='purple')
plt.title('Newspaper Advertising Distribution')
plt.xlabel('Newspaper')
plt.ylabel('Frequency')
plt.show()

# %%
#Distribution of Sales figures
plt.figure(figsize=(8,4))
sns.histplot(data['Sales'],bins=5,color='pink')
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
#Correlation between TV advertising Spending and sales
sns.boxplot(data=data[['TV']])
plt.title('TV')
plt.show()

# %%
sns.boxplot(data=data[['Sales']])
plt.title('Sales')
plt.show()

# %% [markdown]
# rrttggg

# %%
#Correlation between Radio 
sns.boxplot(data=data[['Radio']])
plt.title('Radio')
plt.show()

# %%
#Correlation between Newspaper
sns.boxplot(data=data[['Newspaper']])
plt.title("Newspaper")
plt.show()

# %%
#using heatmap for the correlation
sns.heatmap(data.corr(),annot=True,cmap='viridis');

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data['TV'].mean()
# Out:
# 147.0425

# %%
data['TV']<data['TV'].mean()
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 195     True
# 196     True
# 197    False
# 198    False
# 199    False
# Name: TV, Length: 200, dtype: bool

# %%
#what's the unique value for TV
print(data['TV'].nunique())
# Out:
# 190

# %%
#Line chart correlation between TV and Sales
TV=np.arange(0,10,1)
Sales=np.random.rand(10)
plt.plot(TV,Sales)
plt.title('Line chart for correlation between TV and Sales')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()

# %%
plt.scatter(data['TV'],data['Sales']);

# %%
sns.scatterplot(x='TV', y='Sales',data=data)
plt.title('TV vs Sales')
plt.show()

# %%
data.Sales.describe()
# Out:
# count    200.000000
# mean      15.130500
# std        5.283892
# min        1.600000
# 25%       11.000000
# 50%       16.000000
# 75%       19.050000
# max       27.000000
# Name: Sales, dtype: float64

# %%
#checking for correlation of features
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000
